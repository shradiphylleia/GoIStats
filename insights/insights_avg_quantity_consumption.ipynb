# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import sys
import os

root_dir = os.path.abspath("..")
sys.path.append(root_dir)

# %%
from monthly_avg_quantity_consumption import cereal_data
df_cereal=pd.DataFrame(cereal_data)
df_cereal.head()
# Out:
#                 name   Rice  Wheat  Coarse_Grains  Other_Cereals  \
# 0     Andhra_Pradesh  8.578  0.494          0.209          0.021
# 1  Arunachal_Pradesh  9.524  0.168          0.011          0.009
# 2              Assam  9.011  0.377          0.000          0.005
# 3              Bihar  6.281  4.824          0.032          0.003
# 4       Chhattisgarh  9.474  0.795          0.001          0.001
#
#    Total_Cereals
# 0          9.302
# 1          9.713
# 2          9.393
# 3         11.139
# 4         10.271

# %%
df_cereal_melt=df_cereal.melt(id_vars=['name'],var_name='Category', value_name='Value')

# %%
df_cereal_melt.head()
# Out:
#                 name Category  Value
# 0     Andhra_Pradesh     Rice  8.578
# 1  Arunachal_Pradesh     Rice  9.524
# 2              Assam     Rice  9.011
# 3              Bihar     Rice  6.281
# 4       Chhattisgarh     Rice  9.474

# %%
import seaborn as sns
plt.figure(figsize=(20,5))

sns.barplot(x="name", y="Value", hue="Category", data=df_cereal_melt)

plt.xticks(rotation=90)
plt.xlabel("State")
plt.ylabel("Avg consumption")
plt.title("Grouped Bar Plot of Different Categories by State")
plt.legend(title="food category")

plt.savefig('food.png')

# %%
# most popular: total max in each state

# %%
from math import pi
df_cereal_melt_rice=df_cereal_melt[df_cereal_melt['Category']=='Rice']

# %%
df_cereal_melt_rice
# Out:
#                             name Category   Value
# 0                 Andhra_Pradesh     Rice   8.578
# 1              Arunachal_Pradesh     Rice   9.524
# 2                          Assam     Rice   9.011
# 3                          Bihar     Rice   6.281
# 4                   Chhattisgarh     Rice   9.474
# 5                          Delhi     Rice   1.525
# 6                            Goa     Rice   7.012
# 7                        Gujarat     Rice   2.602
# 8                        Haryana     Rice   0.803
# 9               Himachal_Pradesh     Rice   3.482
# 10                     Jharkhand     Rice   6.786
# 11                     Karnataka     Rice   5.939
# 12                        Kerala     Rice   5.817
# 13                Madhya_Pradesh     Rice   2.648
# 14                   Maharashtra     Rice   3.023
# 15                       Manipur     Rice  11.201
# 16                     Meghalaya     Rice   8.527
# 17                       Mizoram     Rice   9.302
# ...

# %%
states=df_cereal_melt_rice["name"][1:19].tolist()
values=df_cereal_melt_rice["Value"][1:19].tolist()

values.append(values[0])
states.append(states[0])

angles = [n / float(len(states) - 1)*2 * pi for n in range(len(states))]

fig, ax = plt.subplots(figsize=(10,10), subplot_kw=dict(polar=True))

ax.plot(angles, values, linewidth=1.5, linestyle='solid', label="Rice Consumption")
ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(states[:-1],fontsize=10, rotation=15)

plt.title("Rice consumption by State (Radar Chart)")
plt.legend()
plt.show()

# %%
states=df_cereal_melt["name"][19:36].tolist()
values=df_cereal_melt["Value"][19:36].tolist()

values.append(values[0])
states.append(states[0])

angles=[n/float(len(states)-1)*2*pi for n in range(len(states))]

fig,ax=plt.subplots(figsize=(15,12), subplot_kw=dict(polar=True))

ax.plot(angles, values, linewidth=1.5, linestyle='solid', label="Rice Consumption")
ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(states[:-1],fontsize=10, rotation=90)

plt.title("Rice consumption by State (Radar Chart)")
plt.legend()
plt.show()

# %%
df_cereal_melt_wheat=df_cereal_melt[df_cereal_melt['Category']=='Wheat']

# %%
df_cereal_melt_wheat
# Out:
#                             name Category  Value
# 37                Andhra_Pradesh    Wheat  0.494
# 38             Arunachal_Pradesh    Wheat  0.168
# 39                         Assam    Wheat  0.377
# 40                         Bihar    Wheat  4.824
# 41                  Chhattisgarh    Wheat  0.795
# 42                         Delhi    Wheat  4.126
# 43                           Goa    Wheat  2.204
# 44                       Gujarat    Wheat  4.225
# 45                       Haryana    Wheat  7.282
# 46              Himachal_Pradesh    Wheat  5.508
# 47                     Jharkhand    Wheat  3.111
# 48                     Karnataka    Wheat  1.256
# 49                        Kerala    Wheat  0.740
# 50                Madhya_Pradesh    Wheat  6.777
# 51                   Maharashtra    Wheat  4.223
# 52                       Manipur    Wheat  0.022
# 53                     Meghalaya    Wheat  0.147
# 54                       Mizoram    Wheat  0.052
# ...

# %%
states=df_cereal_melt_wheat["name"][1:19].tolist()
values=df_cereal_melt_wheat["Value"][1:19].tolist()

values.append(values[0])
states.append(states[0])

angles = [n/float(len(states)-1)*2 * pi for n in range(len(states))]

fig, ax = plt.subplots(figsize=(15,12), subplot_kw=dict(polar=True))

ax.plot(angles, values, linewidth=1.5, linestyle='solid', label="Wheat Consumption")
ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(states[:-1],fontsize=10, rotation=15)

plt.title("Wheat consumption by State (Radar Chart)")
plt.legend()
plt.show()

# %%
states=df_cereal_melt_wheat["name"][19:36].tolist()
values=df_cereal_melt_wheat["Value"][19:36].tolist()

values.append(values[0])
states.append(states[0])

angles = [n/float(len(states)-1)*2 * pi for n in range(len(states))]

fig, ax = plt.subplots(figsize=(15,12), subplot_kw=dict(polar=True))

ax.plot(angles, values, linewidth=1.5, linestyle='solid', label="Wheat Consumption")
ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(states[:-1],fontsize=10, rotation=15)

plt.title("Wheat consumption by State (Radar Chart)")
plt.legend()
plt.show()

# %%
categories = list(df_cereal.columns[1:])  
N=len(categories)

angles = [n/float(N)*2*pi for n in range(N)]
angles.append(angles[0]) 

fig, axs = plt.subplots(12,3, figsize=(15, 40), subplot_kw=dict(polar=True))
axs = axs.flatten()

for i, row in enumerate(df_cereal.itertuples(index=False)):
    values = list(row[1:]) 
    values.append(values[0]) 

    ax = axs[i-1]
    ax.plot(angles, values, linewidth=1.5, linestyle='solid', label=row[0])
    ax.fill(angles, values, alpha=0.1)

    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(categories,fontsize=10,fontweight='bold')

    ax.set_title(row[0])

for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.suptitle("Cereal Consumption Pattern by State (Radar Chart)")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
